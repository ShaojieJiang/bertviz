# %%
from parlai.agents.s2s_vis.s2s_vis import S2sVisAgent
from bertviz.head_view import show
import json

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min',
#       jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
#   }
# });

# %%
f = open('opt_s2s.json', 'r')
opt = json.load(f)
agent = S2sVisAgent(opt)
model = agent.model
tokenizer = agent
tokenizer.encode = agent.dict.txt2vec
tokenizer.decode = agent.dict.vec2txt
# Out:
# Dictionary: loading dictionary from /Users/shaojie/src/ParlAI/trained/dailydial_s2s/s2s.dict
# [ num words =  19089 ]
# Total parameters: 19488561
# Trainable parameters:  19488561
# [ Loading existing model params from /Users/shaojie/src/ParlAI/trained/dailydial_s2s/s2s ]

# %%
text = "Tell me a little bit about yourself , please ." # s_dimen: 0.96
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "Hi , Jim . How are you ? I haven ' t seen you for a while ." # s_dimen: 0.47
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "Tell me about yourself and your past experience ." # s_dimen: 0.48
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "Are you an art aficionado ?" # s_dimen: 0.9
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "About 50 miles ." # s_dimen: 0.4
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "Oh , I love him too . He not only sings well but also shows perseverance when he encounters difficulties in the contest ." # s_dimen: 0.45
show(model, tokenizer, text, module='cross')
# Out:
#       <span style="user-select:none">
#         Layer: <select id="layer"></select>
#       </span>
#       <div id='vis'></div>

# %%
text = "About 50 miles ." # s_dimen: 0.4
show(model, tokenizer, text, module='cross')
